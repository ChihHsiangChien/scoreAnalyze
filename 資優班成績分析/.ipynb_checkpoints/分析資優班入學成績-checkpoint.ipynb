\
# 0                                                NaN               NaN
# 1                                                NaN               NaN
# 2                                          電子晶片製造與設計            生物醫學數學
# 3                                                NaN               NaN
# 4                                                NaN               NaN
# 5                                                NaN               NaN
# 6                                              半導體製程                 無
# 7                                                NaN               NaN
# 8                                                NaN               NaN
# 9                                                  無                 無
# 10                                                 無                 無
# 11                                               NaN               NaN
# 12                                               NaN               NaN
# 13                                                 無                 無
# 14                                               NaN               NaN
# 15                                               NaN               NaN
# 16                                                 無                 無
# 17                                               NaN               NaN
# 18                                               NaN               NaN
# 19                                               NaN               NaN
# 20                                            業務銷售管理          半導體設備供應鏈
# 21                                               NaN               NaN
# 22                                               NaN               NaN
# 23                                                 無                 無
# 24  Design thinking, UX(User experience design), HCI  產品設計領域相關, 科技藝術相關
# 25                                               NaN               NaN
# 26                                               NaN               NaN
#
#                    校外參觀(提供參觀地點)  校外參觀(協助聯絡)  專題研究提供資源  刊物印刷  \
# 0                           NaN         NaN       NaN   NaN
# 1                           NaN         NaN       NaN   NaN
# 2                             無           無       NaN   NaN
# 3                           NaN         NaN       NaN   NaN
# 4                           NaN         NaN       NaN   NaN
# 5                           NaN         NaN       NaN   NaN
# 6                             無           無  自然科學, 數學    校稿
# 7       目前沒想法，之後有知道合適的地點，再提供參考。         NaN       NaN   NaN
# 8                           NaN         NaN       NaN   NaN
# 9                             無           無       NaN   NaN
# 10                            無           無       NaN   NaN
# 11                          NaN         NaN       NaN  聯絡廠商
# 12                          NaN         NaN       NaN   NaN
# 13                            無           無       NaN   NaN
# 14                          NaN           無       NaN    校稿
# 15                          NaN         NaN       NaN   NaN
# 16                            無           無       NaN   NaN
# 17                          NaN         NaN       NaN   NaN
# 18                          NaN         NaN       NaN   NaN
# 19                          NaN         NaN       NaN   NaN
# 20  Apple office/ google office         NaN    數學, 經費  聯絡廠商
# 21                          NaN         NaN       NaN  聯絡廠商
# 22                          NaN         NaN       NaN   NaN
# 23                            無           無       NaN   NaN
# 24                          NaN         NaN  藝術, 應用科學    校稿
# 25                          NaN         NaN       NaN   NaN
# 26                          NaN         NaN       NaN   NaN
#
#                                                其他協助項目
# 0                                                 NaN
# 1                                                 NaN
# 2                                                   無
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                   無
# 7   不太清楚"專題研究提供資源"大概是要提供那些資源? 如果學校活動有需要家長幫忙，時間上可以安...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                        若有需要幫忙可全力協助
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                  無
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                            都可以參與討論
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
#
# [27 rows x 84 columns]

# %%
df.columns
# Out:
# Index(['導師', '班級', '座號', '學生姓名', 'email', '密碼', '資班座號', '個管教師', '週一專研', '週二專研',
#        '週三專研', '週四社團', '週四選修', '數學性向', '自然性向', '數學能力', '自然能力', '初試總分', '數學實作',
#        '自然實作', '實作', '複試總分', '畢業國小', '國小班級', '生理性別', '出生日期', '身分ID',
#        '出生序(家中排行)', '是否為原就讀國小資優班、資優方案學生', '設籍日', '市(例如:新竹市、新竹縣、苗栗縣，......)',
#        '區(例如:東區、北區、......)', '里(例如:光華里、綠水里、......)', '鄰(例如:11鄰、......)',
#        '地址(例如:光華北街10號)', '聯絡地址', '修正後地址', '聯絡電話(住宅市話)', '監護人', '手機或電話',
#        '緊急聯絡人1', '緊急聯絡人1電話', '緊急聯絡人2', '緊急聯絡人2電話', '家長聯繫email信箱-1',
#        '家長聯繫email信箱-2', '父母成員', '父親姓名', '父親畢業學校及科系', '父親服務機關與職稱', '父親年紀',
#        '父親公司電話', '父親聯繫電話', '母親姓名', '母親畢業學校及科系', '母親服務機關與職稱', '母親年紀', '母親公司電話',
#        '母親聯繫電話', '主要照顧者', '主要學習協助者', '學生與家人相處情形', '學生與家人相處情形若勾選不佳，請簡略敘述原因',
#        '家庭經濟狀況', '家長管教態度', '家長管教態度勾選其它，請簡述管教方式', '請簡述一般家居生活情形',
#        '請簡述學生平日自主學習狀況', '請簡述親子日常互動情形', '興趣種類(一般)', '興趣種類(科學)', '興趣種類(人文)',
#        '數學科現況能力', '自然科現況能力', '其他特殊表現 ', '特殊活動經驗、競賽表現', '其他', '專題演講(本身專長演講)',
#        '專題演講(可協助聯絡專家)', '校外參觀(提供參觀地點)', '校外參觀(協助聯絡)', '專題研究提供資源', '刊物印刷',
#        '其他協助項目'],
#       dtype='object')

# %%
df[['數學性向', '自然性向', '數學能力', '自然能力','數學實作','自然實作']]
# Out:
#     數學性向  自然性向  數學能力  自然能力  數學實作  自然實作
# 0    125   135   106   127    91   112
# 1    141   141   131   127   107   118
# 2    130   141   112    94    99   112
# 3    141   130   129   118   102    92
# 4    141   144   109   127   124   109
# 5    141   135   130   103    93   102
# 6    141   144   124   118    95   104
# 7    136   144   115   118    84   106
# 8    139   135   142   133   113   125
# 9    121   130   114   124   106   112
# 10   124   132   105   118   102   105
# 11   123   147   114   112   112   107
# 12   139   141   123   121   101   102
# 13   123   132   101   112   106   100
# 14   141   150   115   121    88   101
# 15   141   132   131   118   112    99
# 16   130   141   103   121    85   106
# 17   136   135   100   127    89   112
# 18   138   132   108   115    97    95
# 19   137   135   126   121    99   115
# 20   141   127   110   115    95   102
# 21   141   135   102   127   111   124
# 22   141   135   108   115    98    91
# 23   136   120   105   127    90   108
# 24   141   135   149   121   106   109
# 25   138   130   103   100   114    88
# 26   136   127   108   118    91   104

# %%
plt.plot(df[['數學性向', '自然性向', '數學能力', '自然能力','數學實作','自然實作']])
# Out:
# [<matplotlib.lines.Line2D at 0x24cbf7e3470>,
#  <matplotlib.lines.Line2D at 0x24cbf7e35c0>,
#  <matplotlib.lines.Line2D at 0x24cbf7e3710>,
#  <matplotlib.lines.Line2D at 0x24cbf7e3860>,
#  <matplotlib.lines.Line2D at 0x24cbf7e39b0>,
#  <matplotlib.lines.Line2D at 0x24cbf7e3b00>]

# %%
categories = ('自然能力', '自然性向', '數學性向', '數學能力', '數學實作',  '自然實作')

N = len(categories)

angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]

fig, axs = plt.subplots(9, 3, 
                        subplot_kw=dict(projection="polar"),
                        figsize=(13,30),
                       )

#各小圖之間的間隔設定
fig.tight_layout(pad=6, w_pad=3, h_pad=3)

#ax = plt.subplot(111, polar=True)
for i in range(27):

    #plt.xticks(angles[:-1], categories, color='black', size=8, fontproperties = myfont)
    #axs[int(i/3),i%3].set_xticklabels(angles[:-1], categories, color='black',size=8, fontproperties = myfont)
    axs[int(i/3),i%3].set_rlabel_position(0)

    #plt.ylim(80,150)
    #plt.yticks([80,100,120,140], ["80","100","120","140"], color="black", size=7)
    #axs[int(i/3),i%3].set_yticks([80,100,120,140], ["80","100","120","140"])
    axs[int(i/3),i%3].set_ylim(70,160)
    axs[int(i/3),i%3].set_yticks([100,115,130,145])
    axs[int(i/3),i%3].set_yticklabels(['0','1','2','3'])
    
    axs[int(i/3),i%3].set_xticks(angles)
    axs[int(i/3),i%3].set_xticklabels(categories,fontproperties = myfont)
    
    

    #畫全部學生
    for index, row in df.iterrows():
        #scores = (row['數學性向'], row['自然性向'])
        #scores = (row[['數學性向', '數學能力', '數學實作', '自然性向', '自然能力','自然實作']])
        #scores = (row[['數學性向', '自然性向','數學能力', '自然能力', '數學實作',  '自然實作']])
        scores = row[['自然能力', '自然性向', '數學性向','數學能力', '數學實作',  '自然實作', '自然能力']].values.flatten().tolist()
        #plt.plot(scores,color='lightgray', linestyle=':')
        axs[int(i/3),i%3].plot(angles, scores, linewidth=0, color='gray',  marker='o',markeredgecolor='gray',markerfacecolor='none')

    #ax.fill(angles, values, 'b', alpha=0.1)

    #畫單一學生

    data = df.iloc[i]
    single_scores = data[['自然能力', '自然性向', '數學性向','數學能力', '數學實作',  '自然實作', '自然能力']].values.flatten().tolist()
    axs[int(i/3),i%3].plot(angles, single_scores, linewidth=2, color='black', linestyle='-',marker='o')



    title = str(data['班級'])+data['學生姓名']
    axs[int(i/3),i%3].set_title(title,fontproperties = myfont,fontsize= 15)


plt.show()
fig.savefig('資優班入學成績分析.png',dpi = 250)

# %%
# Libraries
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
 
# Set data
df = pd.DataFrame({
'group': ['A','B','C','D'],
'var1': [38, 1.5, 30, 4],
'var2': [29, 10, 9, 34],
'var3': [8, 39, 23, 24],
'var4': [7, 31, 33, 14],
'var5': [28, 15, 32, 14]
})
 
# number of variable
categories=list(df)[1:]
print(categories)
N = len(categories)
 
# We are going to plot the first line of the data frame.
# But we need to repeat the first value to close the circular graph:
values=df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]
values
print(values)
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
print(angles)
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# Draw one axe per variable + add labels
plt.xticks(angles[:-1], categories, color='grey', size=8)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([10,20,30], ["10","20","30"], color="grey", size=7)
plt.ylim(0,40)
 
# Plot data
ax.plot(angles, values, linewidth=1, linestyle='solid')
 
# Fill area
ax.fill(angles, values, 'b', alpha=0.1)

# Show the graph
plt.show()
# Out:
# ['var1', 'var2', 'var3', 'var4', 'var5']
# [38.0, 29, 8, 7, 28, 38.0]
# [0.0, 1.2566370614359172, 2.5132741228718345, 3.7699111843077517, 5.026548245743669, 0.0]

# %%
df.iloc[0]
# Out:
# 導師                                                                      張崇玲
# 班級                                                                      701
# 座號                                                                       11
# 學生姓名                                                                    蔡禹寬
# email                                             1100111@gm.khjh.hc.edu.tw
# 密碼                                                                khjh03336
# 資班座號                                                                      1
# 個管教師                                                                    簡志祥
# 週一專研                                                                     數學
# 週二專研                                                                     理化
# 週三專研                                                                     生物
# 週四社團                                                                     A組
# 週四選修                                                                    NaN
# 數學性向                                                                    125
# 自然性向                                                                    135
# 數學能力                                                                    106
# 自然能力                                                                    127
# 初試總分                                                                    493
# 數學實作                                                                     91
# 自然實作                                                                    112
# 實作                                                                      203
# 複試總分                                                                    899
# 畢業國小                                                                   東門國小
# 國小班級                                                                    601
# 生理性別                                                                      男
# 出生日期                                                    2009-02-19 00:00:00
# 身分ID                                                             O100803336
# 出生序(家中排行)                                                                 3
# 是否為原就讀國小資優班、資優方案學生                                                        是
# 設籍日                                                     2013-07-18 00:00:00
#                                                 ...
# 母親畢業學校及科系                                               美國紐約州立大學水牛城分校英語教學碩士
# 母親服務機關與職稱                                                        中央大學（專任講師）
# 母親年紀                                                                     50
# 母親公司電話                                                       03422751X33810
# 母親聯繫電話                                                           0911680350
# 主要照顧者                                                                父親, 母親
# 主要學習協助者                                                              父親, 母親
# 學生與家人相處情形                                                                良好
# 學生與家人相處情形若勾選不佳，請簡略敘述原因                                                    無
# 家庭經濟狀況                                                                   小康
# 家長管教態度                                                                   民主
# 家長管教態度勾選其它，請簡述管教方式                                                        無
# 請簡述一般家居生活情形                                                              良好
# 請簡述學生平日自主學習狀況                                       自己有興趣的事物積極主動 其餘則需額外提醒催促
# 請簡述親子日常互動情形                   全家有每週一次的家庭會議 大家會互相分享生活大小事 有助於促進家人感情凝聚與增加親子溝通
# 興趣種類(一般)                                                        2.閱讀, 18.其他
# 興趣種類(科學)                                                       2.理化, 8.電腦資訊
# 興趣種類(人文)                                                        1.語文, 10.其他
# 數學科現況能力                                                     理解能力佳，但計算時偶有粗心。
# 自然科現況能力                   從小廣泛閱讀許多科學相關書籍，如最近在讀有關相對論、量子力學的書，會主動涉略各種自然科學知識...
# 其他特殊表現                                                           善於操作電子科技產品
# 特殊活動經驗、競賽表現                               110年(六年級下學期)校內科展獲物理科優等，將代表學校參加市賽。
# 其他                                                                   期許更加自律
# 專題演講(本身專長演講)                                                            NaN
# 專題演講(可協助聯絡專家)                                                           NaN
# 校外參觀(提供參觀地點)                                                            NaN
# 校外參觀(協助聯絡)                                                              NaN
# 專題研究提供資源                                                                NaN
# 刊物印刷                                                                    NaN
# 其他協助項目                                                                  NaN
# Name: 0, Length: 84, dtype: object

# %%
df.iloc[0][['自然能力', '自然性向', '數學性向','數學能力', '數學實作',  '自然實作', '自然能力']].values.flatten().tolist()
# Out:
# [127, 135, 125, 106, 91, 112, 127]
